# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline

# %%
#export
from exp.nb_07a import *

# %%
datasets.URLs.IMAGENETTE_160
# Out:
# 'https://s3.amazonaws.com/fast-ai-imageclas/imagenette2-160'

# %%
path = datasets.untar_data(datasets.URLs.IMAGENETTE_160)
path
# Out:
# PosixPath('/home/adityassrana/.fastai/data/imagenette2-160')

# %%
#export
import PIL,os,mimetypes
Path.ls = lambda x: list(x.iterdir())

# %%
path.ls()
# Out:
# [PosixPath('/home/adityassrana/.fastai/data/imagenette2-160/val'),
#  PosixPath('/home/adityassrana/.fastai/data/imagenette2-160/train')]

# %%
(path/'val').ls()
# Out:
# [PosixPath('/home/adityassrana/.fastai/data/imagenette2-160/val/n03425413'),
#  PosixPath('/home/adityassrana/.fastai/data/imagenette2-160/val/n03417042'),
#  PosixPath('/home/adityassrana/.fastai/data/imagenette2-160/val/n02979186'),
#  PosixPath('/home/adityassrana/.fastai/data/imagenette2-160/val/n03888257'),
#  PosixPath('/home/adityassrana/.fastai/data/imagenette2-160/val/n02102040'),
#  PosixPath('/home/adityassrana/.fastai/data/imagenette2-160/val/n01440764'),
#  PosixPath('/home/adityassrana/.fastai/data/imagenette2-160/val/n03000684'),
#  PosixPath('/home/adityassrana/.fastai/data/imagenette2-160/val/n03028079'),
#  PosixPath('/home/adityassrana/.fastai/data/imagenette2-160/val/n03394916'),
#  PosixPath('/home/adityassrana/.fastai/data/imagenette2-160/val/n03445777')]

# %%
path_tench = path/'val'/'n01440764'

# %%
img_fn = path_tench.ls()[0]
img_fn
# Out:
# PosixPath('/home/adityassrana/.fastai/data/imagenette2-160/val/n01440764/n01440764_7772.JPEG')

# %%
img = PIL.Image.open(img_fn)
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=160x194 at 0x7F4C237B4610>

# %%
plt.imshow(img)

# %%
import numpy
imga = numpy.array(img)

# %%
imga.shape
# Out:
# (194, 160, 3)

# %%
imga[:10,:10,0]
# Out:
# array([[175, 191, 196, 193, ..., 172, 170, 159, 168],
#        [183, 195, 194, 186, ..., 171, 174, 156, 159],
#        [168, 184, 186, 180, ..., 178, 185, 157, 155],
#        [151, 171, 180, 179, ..., 176, 182, 165, 162],
#        ...,
#        [160, 171, 169, 167, ..., 167, 167, 172, 184],
#        [166, 177, 178, 176, ..., 157, 150, 170, 184],
#        [169, 176, 179, 175, ..., 171, 171, 177, 179],
#        [162, 174, 173, 156, ..., 167, 166, 171, 173]], dtype=uint8)
